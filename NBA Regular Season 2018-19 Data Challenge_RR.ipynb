# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %%
# !pip install pandas
import numpy as np
import pandas as pd
nba = pd.read_csv('./nbastats2018-2019.csv', sep=',')
nba
# Out:
# ...
#              Name  Height  Weight                   Team  Age    Salary  \
# 0    Alex Abrines      78     200  Oklahoma City Thunder   25   5455236
# 1      Quincy Acy      79     240           Phoenix Suns   28    213949
# 2    Jaylen Adams      74     190          Atlanta Hawks   22    236854
# 3    Steven Adams      84     265  Oklahoma City Thunder   25  24157304
# 4     Bam Adebayo      82     255             Miami Heat   21   2955840
# ..            ...     ...     ...                    ...  ...       ...
# 516    Trae Young      74     180          Atlanta Hawks   20   5356440
# 517   Cody Zeller      84     240      Charlotte Hornets   26  13528090
# 518  Tyler Zeller      84     253          Atlanta Hawks   29    106974
# 519    Ante Zizic      83     254    Cleveland Cavaliers   22   1952760
# 520   Ivica Zubac      85     240   Los Angeles Clippers   21   1544951
#
#      Points  Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS  \
# ...

# %%
Allstar = nba.set_index('Name').select_dtypes('number')
Allstars = Allstar.idxmax()
Allstars
# Out:
# Height       Boban Marjanovic
# Weight       Boban Marjanovic
# Age              Vince Carter
# Points           James Harden
# Blocks           Myles Turner
# Steals            Paul George
# Assists     Russell Westbrook
# Rebounds       Andre Drummond
# FT%                 Deng Adel
# FTA              James Harden
# FG3%             Trevon Duval
# FG3A             James Harden
# FG%                   Zhou Qi
# FGA              James Harden
# MP               Bradley Beal
# G                 Bam Adebayo
# PER                   Zhou Qi
# OWS              James Harden
# DWS            Andre Drummond
# WS               James Harden
# WS48                  Zhou Qi
# USG            Terrence Jones
# BPM            Gary Payton II
# VORP             James Harden
# dtype: object

# %% [markdown]
# # What was the average age of player in the league?

# %%
# ages = nba["Age"]
average = (nba['Age'].mean())
average
#need to come back and round to whole number
# Out:
# 25.900191938579656

# %% [markdown]
# # What player scored the most points?

# %%
# name= nba['Name']
# points= nba['Points']
player_points = nba[['Name','Points']]
# player_points['Points'].idxmax()
# nba[nba['Points']==nba['Points'].max()]
player_points[player_points['Points']==player_points['Points'].max()]
# Out:
#              Name  Points
# 202  James Harden    36.1

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
MB = nba[['Name','Blocks']]
MB[MB['Blocks']==MB['Blocks'].max()]
# Out:
#              Name  Blocks
# 476  Myles Turner     2.7

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
WP = nba[['Name','WS']]
WP[WP['WS']==WP['WS'].max()]
# Out:
#              Name    WS
# 202  James Harden  15.2

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
shooter = nba[['Name','FG3%']]
shooter[shooter['FG3%']==shooter['FG3%'].max()]
#Trevon Duval
# Out:
#               Name  FG3%
# 147   Trevon Duval   1.0
# 312  Scott Machado   1.0
# 352  Eric Moreland   1.0
# 439  Jordan Sibert   1.0

# %% [markdown]
# # Who played the most minutes during the season

# %%
MP= nba[['Name','MP']]
MP[MP['MP']==MP['MP'].max()]
#Bradley Beal
# Out:
#              Name    MP
# 37   Bradley Beal  36.9
# 179   Paul George  36.9

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
clutch = nba[['Name','PER']]
clutch[clutch['PER']==clutch['PER'].max()]
# Out:
#         Name   PER
# 405  Zhou Qi  80.4

# %% [markdown]
# # What team had the youngest roster?

# %%
# teams_stats = nba.set_index('Team').select_dtypes('number')
# youngest_roster = nba.groupby(['Team','Age'])
# yougest= youngest_roster.mean()
youngest_roster = nba.groupby(["Team",'Age'])
yougest= youngest_roster.sum()
yougest = yougest.reset_index()
yougest
# Out:
#                    Team  Age  Height  Weight  Points  Blocks  Steals  Assists  \
# 0         Atlanta Hawks   20     153     370    28.8     0.5     1.8     11.0
# 1         Atlanta Hawks   21     247     735    28.4     1.1     1.2      3.0
# 2         Atlanta Hawks   22      74     190     3.2     0.1     0.4      1.9
# 3         Atlanta Hawks   23     158     395     6.3     0.1     0.6      1.2
# 4         Atlanta Hawks   24     158     430    21.9     0.8     2.3      4.6
# ..                  ...  ...     ...     ...     ...     ...     ...      ...
# 299  Washington Wizards   27     155     425    13.6     0.3     1.0      5.8
# 300  Washington Wizards   28      76     210    20.7     0.9     1.5      8.7
# 301  Washington Wizards   31      79     215     3.4     0.3     0.4      0.6
# 302  Washington Wizards   32     164     497    16.4     1.0     1.3      2.5
# 303  Washington Wizards   33     163     480    25.3     0.7     2.1      4.1
#
# ...

# %% [markdown]
# # Who is the highest paid player during the season?

# %%
BIGBALLER= nba[['Name','Salary']]
BIGBALLER[BIGBALLER['Salary']==BIGBALLER['Salary'].max()]
#not correct
# Out:
#              Name Salary
# 255  John Jenkins  99290

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
lastpick=nba[['Name','FT%']]
lastpick[lastpick['FT%']==lastpick['FT%'].min()]
Jacob Evans
# Out:
#                    Name  FT%
# 154         Jacob Evans  0.0
# 221   Haywood Highsmith  0.0
# 268      Terrence Jones  0.0
# 325      Tahjere McCall  0.0
# 356  Donatas Motiejunas  0.0
# 360         Dzanan Musa  0.0
# 502       C.J. Williams  0.0
